# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

from config import db_password

import time

# 1. Create a function that takes in three arguments;
# Wikipedia data, Kaggle metadata, and MovieLens rating data (from Kaggle)

def extract_transform_load():
    # 2. Read in the kaggle metadata and MovieLens ratings CSV files as Pandas DataFrames.
    
    kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
    ratings = pd.read_csv(f'{file_dir}/ratings.csv')
    
    # 3. Open the read the Wikipedia data JSON file.
    
    with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
        wiki_movies_raw = json.load(file)
    
    # 4. Read in the raw wiki movie data as a Pandas DataFrame.
    
    wiki_movies_df = pd.DataFrame(wiki_movies_raw)
    
    # 5. Return the three DataFrames
    return wiki_movies_df, kaggle_metadata, ratings

# 6 Create the path to your file directory and variables for the three files. 
file_dir = 'C:/Users/Shiva/REPOSITORIES/Movies-ETL/data'

# Wikipedia data
wiki_file = f'{file_dir}/wikipedia_movies.json'
# Kaggle metadata
kaggle_file = f'{file_dir}/movies_metadata.csv'
# MovieLens rating data.
ratings_file = f'{file_dir}/ratings.csv'

# 7. Set the three variables in Step 6 equal to the function created in Step 1.
wiki_file, kaggle_file, ratings_file = extract_transform_load()

# %%
# 8. Set the DataFrames from the return statement equal to the file names in Step 6. 
wiki_movies_df = wiki_file
kaggle_metadata = kaggle_file
ratings = ratings_file

# %%
# 9. Check the wiki_movies_df DataFrame.
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Predecessor  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...         NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...         NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...         NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...         NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...         NaN
#
#   Founders Area served Products Services Russian Hebrew Revenue  \
# 0      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 1      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 2      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 4      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#   Operating income Polish
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
#
# [5 rows x 193 columns]

# %%
wiki_movies_df.sample(5)
# Out:
#                                                     url    year  \
# 3433  https://en.wikipedia.org/wiki/The_Fighting_Tem...  2003.0
# 3730  https://en.wikipedia.org/wiki/New_York_Minute_...  2004.0
# 4941  https://en.wikipedia.org/wiki/Shutter_(2008_film)  2008.0
# 3328  https://en.wikipedia.org/wiki/Sunshine_State_(...  2002.0
# 4161   https://en.wikipedia.org/wiki/Day_on_Fire_(film)  2006.0
#
#                                   imdb_link                 title  \
# 3433  https://www.imdb.com/title/tt0191133/  Fighting Temptations
# 3730  https://www.imdb.com/title/tt0363282/       New York Minute
# 4941  https://www.imdb.com/title/tt0482599/               Shutter
# 3328  https://www.imdb.com/title/tt0286179/        Sunshine State
# 4161  https://www.imdb.com/title/tt0814072/           Day on Fire
#
#           Directed by                                        Produced by  \
# 3433    Jonathan Lynn  [David Gale, Loretha C. Jones, Benny Medina, J...
# 3730    Dennie Gordon  [Denise Di Novi, Ashley Olsen, Mary-Kate Olsen...
# 4941  Masayuki Ochiai          [Takashige Ichise, Roy Lee, Doug Davison]
# 3328      John Sayles                                       Maggie Renzi
# 4161       Jay Anania  [William Fisch, Larry Rattner, Susan R. Rodger...
#
#                                Screenplay by   Story by  \
# 3433                                     NaN        NaN
# 3730  [Emily Fox, Adam Cooper, Bill Collage]  Emily Fox
# 4941                             Luke Dawson        NaN
# 3328                             John Sayles        NaN
# 4161                                     NaN        NaN
#
#                                                Based on  \
# 3433                                                NaN
# 3730                                                NaN
# 4941  [Shutter, by, Banjong Pisanthanakun, and, Park...
# 3328                                                NaN
# 4161                                                NaN
#
#                                                Starring  ... Predecessor  \
# 3433  [Cuba Gooding Jr., Beyoncé, Mike Epps, Steve H...  ...         NaN
# 3730  [Mary-Kate Olsen, Ashley Olsen, Eugene Levy, A...  ...         NaN
# 4941     [Joshua Jackson, Rachael Taylor, Megumi Okina]  ...         NaN
# 3328                       [Angela Bassett, Edie Falco]  ...         NaN
# 4161  [Olympia Dukakis, Carmen Chaplin, Martin Donov...  ...         NaN
#
#      Founders Area served Products Services Russian Hebrew Revenue  \
# 3433      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3730      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 4941      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3328      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 4161      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#      Operating income Polish
# 3433              NaN    NaN
# 3730              NaN    NaN
# 4941              NaN    NaN
# 3328              NaN    NaN
# 4161              NaN    NaN
#
# [5 rows x 193 columns]

# %%
# 10. Check the kaggle_metadata DataFrame.
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
kaggle_metadata.sample(5)
# Out:
#        adult belongs_to_collection    budget  \
# 10609  False                   NaN         0
# 8564   False                   NaN         0
# 14115  False                   NaN   2000000
# 26312  False                   NaN         0
# 695    False                   NaN  31000000
#
#                                                   genres  \
# 10609  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 8564                      [{'id': 27, 'name': 'Horror'}]
# 14115  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 26312  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 695    [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                 homepage     id    imdb_id original_language  \
# 10609                                NaN  17595  tt0346800                en
# 8564                                 NaN  31383  tt0057181                en
# 14115  http://www.elsecretodesusojos.com  25376  tt1305806                es
# 26312                                NaN  27858  tt0057393                en
# 695                                  NaN  12233  tt0095776                en
#
#                                           original_title  \
# 10609                              Cowards Bend the Knee
# 8564   The Incredibly Strange Creatures Who Stopped L...
# 14115                             El secreto de sus ojos
# 26312                                             PT 109
# 695                                     Oliver & Company
#
#                                                 overview  ... release_date  \
# 10609  Story of Guy Maddin, hockey player for the Mar...  ...   2003-01-01
# 8564   Beatnick Jerry takes his girl, Angie to the ca...  ...   1964-02-10
# 14115  A retired legal counselor writes a novel hopin...  ...   2009-08-13
# 26312  Dramatization of President John F. Kennedy's w...  ...   1963-06-19
# 695    This animated take on Oliver Twist re-imagines...  ...   1988-11-18
#
#           revenue runtime                          spoken_languages    status  \
# 10609         0.0    64.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 8564          0.0    82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14115  33965843.0   129.0  [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 26312         0.0   140.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 695    74151346.0    74.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 10609                                                NaN
# 8564   She Keeps Monsters in Cages for Pets! He Preys...
# 14115                                                NaN
# 26312  Most men would have given up...But not the cre...
# 695                The first Disney movie with attitude.
#
#                                                    title  video vote_average  \
# 10609                              Cowards Bend the Knee  False          8.0
# 8564   The Incredibly Strange Creatures Who Stopped L...  False          2.7
# 14115                           The Secret in Their Eyes  False          7.8
# 26312                                             PT 109  False          6.0
# 695                                     Oliver & Company  False          6.5
#
#       vote_count
# 10609        3.0
# 8564        15.0
# 14115      638.0
# 26312        3.0
# 695        372.0
#
# [5 rows x 24 columns]

# %%
# 11. Check the ratings DataFrame.
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
ratings.count()
# Out:
# userId       26024289
# movieId      26024289
# rating       26024289
# timestamp    26024289
# dtype: int64

# %%
ratings.sample(5)
# Out:
#           userId  movieId  rating   timestamp
# 22550220  234198     1653     5.0  1117731880
# 18381533  190781      592     3.0  1034485252
# 7183368    74108      720     4.0  1439865369
# 1389812    14294     2064     5.0   975212544
# 21520479  223550      950     4.0   939502486
